# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN','NAME','SPECIAL_CONSIDERATIONS','USE_CASE','ORGANIZATION'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION  STATUS     INCOME_AMT  \
# 0              T10       Independent          C1000       1              0
# 1               T3       Independent          C2000       1         1-9999
# 2               T5  CompanySponsored          C3000       1              0
# 3               T3  CompanySponsored          C2000       1    10000-24999
# 4               T3       Independent          C1000       1  100000-499999
#
#    ASK_AMT  IS_SUCCESSFUL
# 0     5000              1
# 1   108590              1
# 2     5000              0
# 3     6692              1
# 4   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# STATUS                 2
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification = application_df['CLASSIFICATION'].value_counts()
classification[classification >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
application_df['CLASSIFICATION'].unique()
# Out:
# array(['C1000', 'C2000', 'C3000', 'C1200', 'C2700', 'C7000', 'C7200',
#        'C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C2100', 'C1238',
#        'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
#        'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
#        'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
#        'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
#        'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
#        'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
#        'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
#        'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
#        'C2150'], dtype=object)

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C7200',
       'C7100', 'C2800', 'C6000', 'C1238',
       'C7120', 'C1800', 'C4100', 'C1400','C2300',
       'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
       'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
       'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
       'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
       'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
       'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
       'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
       'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.dtypes
# Out:
# APPLICATION_TYPE    object
# AFFILIATION         object
# CLASSIFICATION      object
# STATUS               int64
# INCOME_AMT          object
# ASK_AMT              int64
# IS_SUCCESSFUL        int64
# dtype: object

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df = pd.get_dummies(application_df, columns = ['APPLICATION_TYPE','CLASSIFICATION','INCOME_AMT','AFFILIATION'])

# %%
df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0                         1                     0                     0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = df['IS_SUCCESSFUL'].values.reshape(-1, 1)
X = df.drop('IS_SUCCESSFUL',axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, random_state=50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler1 = scaler.fit(X_train1)

# Scale the data
X_train_scaled1 = X_scaler1.transform(X_train1)
X_test_scaled1 = X_scaler1.transform(X_test1)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=42))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=45, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3440
#
#  dense_1 (Dense)             (None, 45)                3645
#
#  dense_2 (Dense)             (None, 1)                 46
#
# ...
# Total params: 7,131
# Trainable params: 7,131
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train1,y_train1,epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 64717.1172 - accuracy: 0.4892
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 37351.5703 - accuracy: 0.4822
# Epoch 3/50
# 804/804 [==============================] - 2s 2ms/step - loss: 70584.9219 - accuracy: 0.4912
# Epoch 4/50
# 804/804 [==============================] - 2s 2ms/step - loss: 15221.2002 - accuracy: 0.5000
# Epoch 5/50
# 804/804 [==============================] - 2s 2ms/step - loss: 24479.7559 - accuracy: 0.5189
# Epoch 6/50
# 804/804 [==============================] - 2s 2ms/step - loss: 15949.9385 - accuracy: 0.4865
# Epoch 7/50
# 804/804 [==============================] - 2s 3ms/step - loss: 38380.9062 - accuracy: 0.4937
# Epoch 8/50
# 804/804 [==============================] - 2s 2ms/step - loss: 16075.5518 - accuracy: 0.5031
# Epoch 9/50
# 804/804 [==============================] - 2s 2ms/step - loss: 22880.9297 - accuracy: 0.5160
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled1,y_test1,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.8736 - accuracy: 0.7046 - 533ms/epoch - 2ms/step
# Loss: 0.8735901713371277, Accuracy: 0.7046064138412476

# %%
# # model 2

# %%
application_df2 = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df2.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df2 = application_df2.drop(['EIN','NAME'], axis=1)

# Determine the number of unique values in each column.
application_df2.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df2['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T8','T7','T10','T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df2['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df2['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: APPLICATION_TYPE, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification = application_df2['CLASSIFICATION'].value_counts()
classification[classification >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C2100','C3000','C2700', 'C7000', 'C7200',
       'C1700', 'C4000', 'C7100', 'C2800', 'C6000','C1238',
       'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
       'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
       'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
       'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
       'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
       'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
       'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
       'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
       'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df2['CLASSIFICATION'] = application_df2['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df2['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
df2 = pd.get_dummies(application_df2, columns = ['APPLICATION_TYPE','AFFILIATION','CLASSIFICATION','USE_CASE','ORGANIZATION','INCOME_AMT','SPECIAL_CONSIDERATIONS'])

# %%
df2
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  \
# 0                         1                     0                     0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y2 = df2['IS_SUCCESSFUL'].values.reshape(-1, 1)
X2 = df2.drop('IS_SUCCESSFUL',axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X2, y2, random_state=50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=45))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=45, activation="relu"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 80)                3680
#
#  dense_7 (Dense)             (None, 45)                3645
#
#  dense_8 (Dense)             (None, 1)                 46
#
# ...
# Total params: 7,371
# Trainable params: 7,371
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn2.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 71371.2578 - accuracy: 0.4846
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 60489.8359 - accuracy: 0.5037
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 42789.7070 - accuracy: 0.4977
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 35838.9219 - accuracy: 0.4947
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 14634.7295 - accuracy: 0.5157
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 20042.8203 - accuracy: 0.5128
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 10217.3389 - accuracy: 0.4946
# Epoch 8/100
# 804/804 [==============================] - 4s 4ms/step - loss: 16804.8223 - accuracy: 0.5008
# Epoch 9/100
# 804/804 [==============================] - 4s 4ms/step - loss: 5861.4336 - accuracy: 0.4830
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.8133 - accuracy: 0.4624 - 484ms/epoch - 2ms/step
# Loss: 0.8132988214492798, Accuracy: 0.462390661239624

# %%
## model 3

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(tf.keras.layers.Dense(units=70, activation="relu", input_dim=45))

# # Second hidden layer
nn3.add(tf.keras.layers.Dense(units=55, activation="sigmoid"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 70)                3220
#
#  dense_13 (Dense)            (None, 55)                3905
#
#  dense_14 (Dense)            (None, 1)                 56
#
# ...
# Total params: 7,181
# Trainable params: 7,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn3.fit(X_train,y_train,epochs=40)
# Out:
# Epoch 1/40
# 804/804 [==============================] - 3s 2ms/step - loss: 0.6958 - accuracy: 0.5236
# Epoch 2/40
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6921 - accuracy: 0.5257
# Epoch 3/40
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6921 - accuracy: 0.5269
# Epoch 4/40
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6918 - accuracy: 0.5270
# Epoch 5/40
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6918 - accuracy: 0.5264
# Epoch 6/40
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6919 - accuracy: 0.5297
# Epoch 7/40
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6920 - accuracy: 0.5281
# Epoch 8/40
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6920 - accuracy: 0.5285
# Epoch 9/40
# 804/804 [==============================] - 3s 3ms/step - loss: 0.6918 - accuracy: 0.5288
# Epoch 10/40
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.6947 - accuracy: 0.5226 - 485ms/epoch - 2ms/step
# Loss: 0.6946781873703003, Accuracy: 0.5225656032562256

# %%
# Export our model to HDF5 file
from google.colab import drive
drive.mount('/content/drive')

# Save the model weights to your Google Drive
nn.save_weights('/content/drive/My Drive/Colab Notebooks/AlphabetSoupCharity_Optimization.h5')
# Out:
# Mounted at /content/drive
